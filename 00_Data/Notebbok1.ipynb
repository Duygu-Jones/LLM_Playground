# %% [markdown]
# # SATIS-URETIM TAKIP DATA REVIEW

# %%
import pandas as pd

# %%
df_2018 = pd.read_excel('01_Satis_Uretim/2018-Uretim_Takip.xlsx')
df_2019 = pd.read_excel('01_Satis_Uretim/2019-Uretim_Takip.xlsx')
df_2020 = pd.read_excel('01_Satis_Uretim/2020-Uretim_Takip.xlsx')
df_2021 = pd.read_excel('01_Satis_Uretim/2021-Uretim_Takip.xlsx')
df_2022 = pd.read_excel('01_Satis_Uretim/2022-Uretim_Takip.xlsx')
df_2023 = pd.read_excel('01_Satis_Uretim/2023-Uretim_Takip.xlsx')
df_2023_ends = pd.read_excel('01_Satis_Uretim/2023-Uretim_Takip-Endutriyel.xlsx')
df_2024 = pd.read_excel('01_Satis_Uretim/2024-Uretim_Takip.xlsx')
df_2024_satis_analiz = pd.read_excel('01_Satis_Uretim/2024-Satis_Analiz.xlsx')

df_chatbot_soru = pd.read_excel('01_Satis_Uretim/chotbox2-Sentebiolab-Musteri-Sorular.xlsx')

# %%
df_2018.head(3)
# Out:
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2018/001     2018-01-04
# 1                 DMO                        2018/072     2017-12-28
# 2                ÖZEL                        2018/071     2017-12-25
#
#                          SİPARİŞİ VEREN/2018  \
# 0  YENİ HAYAT TIP MERKEZİ-ORJİN SAĞLIK HİZM.
# 1                         DMO GENEL MÜDÜRLÜK
# 2                   BURSA RETİNA GÖZ MERKEZİ
#
#                                   KURULUM YERİ /2018        İL ÜRÜN MODELİ  \
# 0          YENİ HAYAT TIP MERKEZİ-ORJİN SAĞLIK HİZM.  İSTANBUL  STR 6610 D
# 1  T.C. GIDA TARIM VE HAYV. BAKANLIĞI GIDA VE KON...    ANKARA      7717 S
# 2                           BURSA RETİNA GÖZ MERKEZİ     BURSA  ERS 4410 D
#
#                                             ÜRÜN ADI       LİTRE      SERİ NO  \
# 0                  422 LT ÇİFT KAPILI OTOKLAV CİHAZI   422 LİTRE  2018/01-001
# ...
