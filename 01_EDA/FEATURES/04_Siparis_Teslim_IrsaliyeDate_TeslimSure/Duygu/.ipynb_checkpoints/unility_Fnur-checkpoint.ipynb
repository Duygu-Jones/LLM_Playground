# %%
import os
import pandas as pd
import seaborn as sns

# %%
# UTILS ADDINDAKI FONKSIYONLARIMIZI DERLEDIGIMIZ MODULU BU NOTEBOOK ICINE IMPORT EDIYORUZ

import sys

# 'utils1.py' dosyasının bulunduğu dizin (kendi bilgisayarındaki dosya yolunu kopyala-al);
sys.path.append(r'C:\Users\ASUS\Desktop\Internship\utils\utils1.py')

# 'utils1.py' dosyasında olusturulan Utils sınıfını import et
from utils1 import UtilsAnalysis

# Utils sınıfından bir nesne oluştur
utils = UtilsAnalysis()

# %%
# utils nesnesindeki tüm fonksiyonları ve öznitelikleri listelemek için
dir(utils)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'detect_anomalies',
#  'df',
#  'duplicate_values',
#  'find_non_numeric_values',
#  'get_value_count',
#  'missing_values',
#  'na_ratio_plot',
#  'numeric_summary',
#  'object_summary',
#  'set_column']

# %%
help(utils.missing_values)
# Out:
# Help on method missing_values in module utils1:
#
# missing_values() method of utils1.UtilsAnalysis instance
#     DataFrame'deki eksik değerlerin sayısını ve yüzdesini hesaplar.

# %%
# Dosya yolunu belirtelim
file_path = r'C:\Users\ASUS\Desktop\GOLDBERG_MED_INT1_PROJECT\00_Data\01_Satis_Uretim\03_Satis_Uretim_Merged_Data\merged_satis_uretim_data_26_10_2024.csv'

# CSV dosyasını okuyalım
try:
    df_total = pd.read_csv(file_path)
    # İlk birkaç satırı göstereceğiz
    df_total.head()
except FileNotFoundError:
    "Dosya yolunda bir hata olabilir veya dosya mevcut olmayabilir."
    
df_total.head()
# Out:
#           kategori satis_turu siparis_no siparis_tarihi  \
# 0  AMELIYAT MASASI       ÖZEL   2018/006     2018-06-29
# 1  AMELIYAT MASASI       DEMO   2018/007     2018-02-14
# 2  AMELIYAT MASASI       ÖZEL   2018/008     2018-10-23
# 3  AMELIYAT MASASI   YURTDIŞI   2018/009     2018-09-03
# 4  AMELIYAT MASASI   YURTDIŞI   2018/011     2018-02-28
#
#                     siparisi_veren                           kurulum_yeri  \
# 0             ÖZEL FSM TIP MERKEZİ                   ÖZEL FSM TIP MERKEZİ
# 1                             DEMO  DERİNCE EĞİTİM VE ARAŞTIRMA HASTANESİ
# 2  İZMİR KATİP ÇELEBİ ÜNİVERSİTESİ        İZMİR KATİP ÇELEBİ ÜNİVERSİTESİ
# 3     COOL DEE PA ELEKTRIC CO LTD.           COOL DEE PA ELEKTRIC CO LTD.
# 4                         YÜKSELİŞ                         DR.ORUC IBADOV
#
#            il  urun_modeli         urun_adi litre      seri_no teslim_suresi  \
# 0    İSTANBUL  GOLDBERG 5S  AMELİYAT MASASI     *  2018/02-012        20 GÜN
# 1     KOCAELİ  GOLDBERG 5S  AMELİYAT MASASI     *  2018/02-003        21 GÜN
# 2       İZMİR  GOLDBERG 5S  AMELİYAT MASASI     *  2018/02-029        DERHAL
# 3     TAYLAND  GOLDBERG 5S  AMELİYAT MASASI     *  2018/02-022         7 GÜN
# 4  AZERBEYCAN  GOLDBERG 5S  AMELİYAT MASASI     *  2018/02-004         8 GÜN
#
#   teslim_tarihi  siparis_durumu irsaliye_tarihi aciklama solusyon_fatura  \
# 0    2018-07-18             NaN             NaN      NaN             NaN
# 1           NaN             NaN             NaN      NaN             NaN
# 2           NaN             NaN             NaN      NaN             NaN
# 3    2018-09-07             NaN             NaN      NaN             NaN
# 4           NaN             NaN             NaN      NaN             NaN
#
#   bidon_acilisi  uts_no
# 0           NaN     NaN
# 1           NaN     NaN
# 2           NaN     NaN
# 3           NaN     NaN
# 4           NaN     NaN

# %%
#Kullanıcıdan bir DataFrame alır. Ve aşağıdaki tüm işlemleri buna göre yapar. Tekrar data frame tanıtmaya gerek kalmaz. 
utils.df = df_total

# %%
utils.object_summary()
# Out:
# 1. Data shape (rows, columns): (32646, 19)
# 2. Number of duplicate rows: 169
#                   Dtype  Counts  Nulls  NullPercent                      Top  \
# kategori         object   32646      0     0.000000                   KARTUS
# satis_turu       object   29480   3166     9.697972                     ÖZEL
# siparis_no       object   27743   4903    15.018685                  2024/71
# siparis_tarihi   object   30830   1816     5.562703      2024-05-22 00:00:00
# siparisi_veren   object   31216   1430     4.380322                  ROMANYA
# kurulum_yeri     object    2519  30127    92.283894                 KAMBOÇYA
# il               object   31083   1563     4.787723                   ANKARA
# urun_modeli      object    2450  30196    92.495252              GOLDBERG 5S
# urun_adi         object   31119   1527     4.677449                   KARTUŞ
# litre            object    2245  30401    93.123200                        *
# seri_no          object   32443    203     0.621822                  SERİSİZ
# teslim_suresi    object    2252  30394    93.101758                   65 GÜN
# teslim_tarihi    object    2117  30529    93.515285      2020-07-14 00:00:00
# irsaliye_tarihi  object      90  32556    99.724315
# aciklama         object   11627  21019    64.384611                    SATIŞ
# solusyon_fatura  object    5369  27277    83.553881  25.4.2019-HPS2019-00387
# bidon_acilisi    object    5369  27277    83.553881               2020-01-05
#
#                  Frequency  Uniques  \
# kategori             30126        7
# satis_turu            8977       57
# siparis_no            1000     2649
# siparis_tarihi        1027     1449
# siparisi_veren        1341      856
# kurulum_yeri           137      775
# il                    4386      194
# urun_modeli            215      176
# urun_adi             28794      124
# litre                  269       59
# seri_no                  8    32310
# teslim_suresi          269      320
# teslim_tarihi           42      892
# irsaliye_tarihi         82        9
# aciklama              2657      163
# solusyon_fatura       1799        4
# bidon_acilisi         1521        8
#
#                                                       UniqueValues
# kategori         AMELIYAT MASASI, OTOKLAV, HIDROJEN PEROKSIT, K...
# satis_turu       ÖZEL, DEMO, YURTDIŞI, DMO, İHALE, 2021 DE SATI...
# siparis_no       2018/006, 2018/007, 2018/008, 2018/009, 2018/0...
# siparis_tarihi   2018-06-29, 2018-02-14, 2018-10-23, 2018-09-03...
# siparisi_veren   ÖZEL FSM TIP MERKEZİ, DEMO, İZMİR KATİP ÇELEBİ...
# kurulum_yeri     ÖZEL FSM TIP MERKEZİ, DERİNCE EĞİTİM VE ARAŞTI...
# il               İSTANBUL, KOCAELİ, İZMİR, TAYLAND, AZERBEYCAN,...
# urun_modeli      GOLDBERG 5S, ERM 2000 F, STR 2000 F, 2000 F, G...
# urun_adi         AMELİYAT MASASI, 422 LT ÇİFT KAPILI OTOKLAV Cİ...
# litre            *, OBEZ, nan, aşağıda, 422 LİTRE, 2000 LİTRE, ...
# seri_no          2018/02-012, 2018/02-003, 2018/02-029, 2018/02...
# teslim_suresi    20 GÜN, 21 GÜN, DERHAL, 7 GÜN, 8 GÜN, 60 GÜN, ...
# teslim_tarihi    2018-07-18, nan, 2018-09-07, 2019-01-01, 2018-...
# irsaliye_tarihi  nan,  , cihaz gitti., kazan yok - nerede, DUBA...
# aciklama         nan, ÜCRETSİZ, DEMO, SÖZLEŞME, DEĞİŞİM, SATIŞ,...
# solusyon_fatura  nan, 19.4.2018-HPS2018-00311, 25.4.2019-HPS201...
# bidon_acilisi    nan, 2019-01-02, 2019-04-29, 2019-10-08, 2020-...

# %%
utils.numeric_summary()
# Out:
# 1. Data shape (rows, columns): (32646, 19)
# 2. Number of duplicate rows: 169
#                   Dtype  Counts  Nulls  NullPercent          Mean       Std  \
# siparis_durumu  float64       0  32646   100.000000           NaN       NaN
# uts_no          float64       3  32643    99.990811  8.697613e+12  4.041452
#
#                          Min           25%  50% (Median)           75%  \
# siparis_durumu           NaN           NaN           NaN           NaN
# uts_no          8.697613e+12  8.697613e+12  8.697613e+12  8.697613e+12
#
#                          Max
# siparis_durumu           NaN
# uts_no          8.697613e+12

# %%
utils.get_value_count()
# Out:
# Mevcut sütunlar:
# kategori | satis_turu | siparis_no | siparis_tarihi | siparisi_veren | kurulum_yeri | il | urun_modeli | urun_adi | litre | seri_no | teslim_suresi | teslim_tarihi | siparis_durumu | irsaliye_tarihi | aciklama | solusyon_fatura | bidon_acilisi | uts_no
#
# Lütfen analiz etmek istediğiniz sütun adını yazınız (örn: 'SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO'):
# Sütun adı: kategori
# 'kategori' sütunu başarıyla seçildi!
#             kategori  counts percent
# 0             KARTUS   30126  92.28%
# 1            OTOKLAV    1242   3.80%
# 2    AMELIYAT MASASI     475   1.46%
# 3             YIKAMA     393   1.20%
# 4     REVERSE OSMOS      204   0.62%
# 5  HIDROJEN PEROKSIT     135   0.41%
# 6            OKSIJEN      71   0.22%

# %%
utils.duplicate_values()
# Out:
# 169 adet tekrarlı gözlem bulundu. Bunlar silinecek.
# 169 adet tekrarlı gözlem silindi.
#               kategori satis_turu siparis_no siparis_tarihi  \
# 0      AMELIYAT MASASI       ÖZEL   2018/006     2018-06-29
# 1      AMELIYAT MASASI       DEMO   2018/007     2018-02-14
# 2      AMELIYAT MASASI       ÖZEL   2018/008     2018-10-23
# 3      AMELIYAT MASASI   YURTDIŞI   2018/009     2018-09-03
# 4      AMELIYAT MASASI   YURTDIŞI   2018/011     2018-02-28
# ...                ...        ...        ...            ...
# 32638          OKSIJEN   YURTDIŞI   2022/364     2022-02-02
# 32642          OKSIJEN   YURTDIŞI   2022/156     2024-02-27
# 32643          OKSIJEN   YURTDIŞI   2022/161     2022-03-03
# 32644          OKSIJEN   YURTDIŞI   2022/163     2024-06-11
# 32645          OKSIJEN   YURTDIŞI   2024/283     2024-09-25
#
#                         siparisi_veren                           kurulum_yeri  \
# 0                 ÖZEL FSM TIP MERKEZİ                   ÖZEL FSM TIP MERKEZİ
# 1                                 DEMO  DERİNCE EĞİTİM VE ARAŞTIRMA HASTANESİ
# 2      İZMİR KATİP ÇELEBİ ÜNİVERSİTESİ        İZMİR KATİP ÇELEBİ ÜNİVERSİTESİ
# 3         COOL DEE PA ELEKTRIC CO LTD.           COOL DEE PA ELEKTRIC CO LTD.
# 4                             YÜKSELİŞ                         DR.ORUC IBADOV
# ...                                ...                                    ...
# 32638                             IRAK                                   IRAK
# 32642                          CEZAYİR                                CEZAYİR
# 32643                             STOK                                   STOK
# 32644                          CEZAYİR                                CEZAYİR
# 32645                          CEZAYİR                                CEZAYİR
#
#                il    urun_modeli  \
# 0        İSTANBUL    GOLDBERG 5S
# 1         KOCAELİ    GOLDBERG 5S
# 2           İZMİR    GOLDBERG 5S
# 3         TAYLAND    GOLDBERG 5S
# 4      AZERBEYCAN    GOLDBERG 5S
# ...           ...            ...
# 32638        IRAK  GOLDBERG 22 V
# 32642     CEZAYİR    OXY-GOLD 37
# 32643        STOK    OXY-GOLD 30
# 32644     CEZAYİR    OXY-GOLD 30
# 32645     CEZAYİR    OXY-GOLD 37
#
#                                               urun_adi litre      seri_no  \
# 0                                      AMELİYAT MASASI     *  2018/02-012
# 1                                      AMELİYAT MASASI     *  2018/02-003
# 2                                      AMELİYAT MASASI     *  2018/02-029
# 3                                      AMELİYAT MASASI     *  2018/02-022
# 4                                      AMELİYAT MASASI     *  2018/02-004
# ...                                                ...   ...          ...
# 32638                        22 OKSİJEN ÜRETİM SİSTEMİ   NaN  2022/06-006
# 32642  OXY-GOLD 37 OKSİJEN ÜRETİM  VE DEPOLAMA SİSTEMİ   NaN  2024/06-001
# 32643  OXY-GOLD 30 OKSİJEN ÜRETİM  VE DEPOLAMA SİSTEMİ   NaN  2024/06-003
# 32644  OXY-GOLD 30 OKSİJEN ÜRETİM  VE DEPOLAMA SİSTEMİ   NaN  2024/06-005
# 32645  OXY-GOLD 37 OKSİJEN ÜRETİM  VE DEPOLAMA SİSTEMİ   NaN  2024/06-006
#
#       teslim_suresi teslim_tarihi  siparis_durumu irsaliye_tarihi aciklama  \
# 0            20 GÜN    2018-07-18             NaN             NaN      NaN
# 1            21 GÜN           NaN             NaN             NaN      NaN
# 2            DERHAL           NaN             NaN             NaN      NaN
# 3             7 GÜN    2018-09-07             NaN             NaN      NaN
# 4             8 GÜN           NaN             NaN             NaN      NaN
# ...             ...           ...             ...             ...      ...
# 32638           267    2022-10-27             NaN             NaN      NaN
# 32642        60 gün    2024-03-11             NaN             NaN      NaN
# 32643        60 gün    2024-03-12             NaN             NaN      NaN
# 32644        60 gün    2024-06-13             NaN             NaN      NaN
# 32645        60 gün    2024-10-13             NaN             NaN      NaN
#
#       solusyon_fatura bidon_acilisi        uts_no
# 0                 NaN           NaN           NaN
# 1                 NaN           NaN           NaN
# 2                 NaN           NaN           NaN
# 3                 NaN           NaN           NaN
# 4                 NaN           NaN           NaN
# ...               ...           ...           ...
# 32638             NaN           NaN           NaN
# 32642             NaN           NaN  8.697613e+12
# 32643             NaN           NaN  8.697613e+12
# 32644             NaN           NaN  8.697613e+12
# 32645             NaN           NaN           NaN
#
# [32477 rows x 19 columns]

# %%
utils.missing_values()
# Out:
# Eksik değerlerin sütun bazında dökümü aşağıda verilmiştir:
#                  Eksik Değer Sayısı    Yüzde
# kategori                          0    0.00%
# satis_turu                     3136    9.66%
# siparis_no                     4870   15.00%
# siparis_tarihi                 1792    5.52%
# siparisi_veren                 1406    4.33%
# kurulum_yeri                  30037   92.49%
# il                             1520    4.68%
# urun_modeli                   30106   92.70%
# urun_adi                       1501    4.62%
# litre                         30268   93.20%
# seri_no                         126    0.39%
# teslim_suresi                 30303   93.31%
# teslim_tarihi                 30439   93.72%
# siparis_durumu                32477  100.00%
# irsaliye_tarihi               32387   99.72%
# aciklama                      20892   64.33%
# solusyon_fatura               27191   83.72%
# bidon_acilisi                 27191   83.72%
# uts_no                        32474   99.99%

# %%
utils.na_ratio_plot()
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Eksik değer sayısı (0'dan fazla olan sütunlar):
# satis_turu          3136
# siparis_no          4870
# siparis_tarihi      1792
# siparisi_veren      1406
# kurulum_yeri       30037
# il                  1520
# urun_modeli        30106
# urun_adi            1501
# litre              30268
# seri_no              126
# teslim_suresi      30303
# teslim_tarihi      30439
# siparis_durumu     32477
# irsaliye_tarihi    32387
# aciklama           20892
# solusyon_fatura    27191
# bidon_acilisi      27191
# uts_no             32474
# dtype: int64

# %%
utils.detect_anomalies()
# Out:
# Mevcut sütunlar:
# kategori | satis_turu | siparis_no | siparis_tarihi | siparisi_veren | kurulum_yeri | il | urun_modeli | urun_adi | litre | seri_no | teslim_suresi | teslim_tarihi | siparis_durumu | irsaliye_tarihi | aciklama | solusyon_fatura | bidon_acilisi | uts_no
#
# Lütfen analiz etmek istediğiniz sütun adını yazınız:
# Sütun adı: satis_turu
# 'satis_turu' sütununda alfasayısal olmayan karakterler tespit edildi:
# '2021 DE SATIŞA ÇEVRİLDİ, 2021 DE DEMO OLARAK GİTTİ, 2022 DE SATIŞ OLDU, 2024 YILINA AKTARILDI, DOĞRUDAN TEMİN, 2024 e aktarıldı, 2023 YILINA AKTARILDI, 2024 YILANA AKTARILDI, 2023 YILANA AKTARILDI, DMO-YÜKSELİŞ, İHALE SATIŞ, İHALE  NUMUNE, İHALE NUMUNE, İHALE   , İHALE    , CİHAZIN YANINDA, İHALE NUMUNESİ, İHALE  , PATLAYAN YERİNE, kartuş aktı değiştirildi., ETİKET YOK, iptal edilmiş, ARIZALI ÇIKMIŞ., ARIZALI ÇIKTI, ETİKET YIRTILDI, ALİ BEY, YURT DIŞI, ÖZEL , İHALE -İŞ ARTIŞI, HİZMET ALIMI, İHALE- NUMUNESİ, İHALE -HİZMET, MAL FAZLASI'

# %%
utils.find_non_numeric_values()
# Out:
# Mevcut sütunlar:
# kategori | satis_turu | siparis_no | siparis_tarihi | siparisi_veren | kurulum_yeri | il | urun_modeli | urun_adi | litre | seri_no | teslim_suresi | teslim_tarihi | siparis_durumu | irsaliye_tarihi | aciklama | solusyon_fatura | bidon_acilisi | uts_no
#
# Lütfen analiz etmek istediğiniz sütun adını yazınız (örn: 'siparis_no'):
# Sütun adı: teslim_tarihi
# 'teslim_tarihi' sütununda bulunan benzersiz sayısal olmayan değerler:
# {' ',
#  ' DERHAL ',
#  ' DERHAL DERHAL ',
#  ' GÜN ',
#  ' IRAKTI STOK OLDU ',
#  ' SERVİSİN MASASI YERİNE YENİ BİNASI İÇİN DEMO OLARAK BIRAKILDI ',
#  ' cihaz geri geldi. ',
#  '-',
#  '-TL YUSUF BAYRAMA VERİLDİ. YUSUF BAYRAMA VERİLDİ. ',
#  '.',
#  '..',
#  '/',
#  ':'}
