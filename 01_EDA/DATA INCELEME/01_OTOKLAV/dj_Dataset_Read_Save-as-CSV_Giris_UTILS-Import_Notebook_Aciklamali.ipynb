# %% [markdown]
# # DATA GORUNTULEME DF VE CVS OLARAK KAYIT ETME

# %% [markdown]
# **Bu Dosya sadece dosya yollarından kendi kategorimize ulaşmayı ve o kategoriyi yıl bazında csv dosyası kayıt etmeyi içerir.Bu işlemi yaptıktan sonra çalışmalarınıza ayrı notebook da herzamanki işlemler ile devam edebilirsiniz.**
#
#
# -1. Dosyaların sadece yolunu kullanarak okuyacağız. Bunun için daha önce gönderilen videoya bakalım.
#
# -2. Sürekli bu işlemi yapmamak için aldığımız sayfayı csv dosyası olarak kayıt edeceğiz. Burada dikkat edilmesi gereken nokta çalışılan notebook ve exel aynı klasörde değil o yüzden dosya yollarını alarak devam ediyoruz. Dosya yollarının sizinki ile aynı olmasına dikkat edilmeli.
#
# - Sadece 2 farklı fonksiyon var. (Dosyanın kalabalık olması her dosyaya bu fonksiyonları uyguladığım için )
#
# Eğer takılırsanız lütfen bana ulaşın ya da watsapdan yazalım :) Fatma Nur A.

# %% [markdown]
# ## Import Local Fonction Modul 'utils1'

# %%
# UTILS ADDINDAKI FONKSIYONLARIMIZI DERLEDIGIMIZ MODULU BU NOTEBOOK ICINE IMPORT EDIYORUZ

import sys

# 'utils1.py' dosyasının bulunduğu dizin (kendi bilgisayarındaki dosya yolunu kopyala-al);
sys.path.append(r'C:/Users/duygu/Desktop/00-GitHub-Repo/00-1INTERNSHIP/INT1_PROJECT/UTILITIES/')

# 'utils1.py' dosyasında olusturulan Utils sınıfını import et
from utils1 import Utils

# Utils sınıfından bir nesne oluştur
utils = Utils()

# %%
# utils nesnesindeki tüm fonksiyonları ve öznitelikleri listelemek için
dir(utils)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'detect_anomalies',
#  'df',
#  'duplicate_values',
#  'find_non_numeric_values',
#  'get_value_count',
#  'missing_values',
#  'na_ratio_plot',
#  'numeric_summary',
#  'object_summary',
#  'read_excel_page',
#  'rename_columns_by_position',
#  'save_and_load_csv']

# %%
help(Utils.read_excel_page)
# Out:
# Help on function read_excel_page in module utils1:
#
# read_excel_page(self, base_dir, file_name, selected_page)
#     Excel dosyasındaki bir sayfayı seçip okuyan fonksiyon.

# %%
help(Utils.save_and_load_csv)
# Out:
# Help on function save_and_load_csv in module utils1:
#
# save_and_load_csv(self, df, filename, dir_path)
#     DataFrame'i belirtilen dizine CSV olarak kaydeder ve tekrar yükler.

# %% [markdown]
# ## 2018 Otoklav

# %% [markdown]
# ### Excel dosyasi icindeki page'leri okuma:
#
# - `utils` nesnesini kullanarak `utils.read_excel_page()` fonksiyonu cagir
# - Lokal Proje github dosyasindaki dataset ve icindeki dosya yollarini kopyala-yapistir-Enter

# %%
# Excel Dosyasini okuma:

#(Lokal Proje github dosyasindaki dataset ve icindeki dosya yollarini kopyala-yapistir-Enter)
# 1) Input olarak gelen kutuya Dataset yolunu giriniz : 01_Satis_Uretim 
# 2) Excel data dosya yolunu giriniz : 2018-Uretim_Takip.xlsx 
# 3) Fonksiyon Excel dosyasindaki page isimlerini listeler(Kendi kategorinizi seçip kopyala-yapıştır-Enter): 2018-01 OTOKLAV

# Excel dosyasından bir sayfa oku ve DataFrame'i elde et
df_otoklav_18 = utils.read_excel_page()

df_otoklav_18.head(3)
# Out:
# Lütfen Dataset dosya yolunu girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim):  C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\00_Data\01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx):  C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\00_Data\01_Satis_Uretim\2018-Uretim_Takip.xlsx
# Dosyadaki sayfa adları: ['2018-01 OTOKLAV', '2018-02-AMELİYAT MASASI', '2018-04-HİDROJEN PEROKSİT', '2018-05-YIKAMA', '2018-06-OKSİJEN SİSTEMİ', '2018-07-KARTUŞ', '2018-08-REVERSE OSMOS ', '2018-DEMO GİDEN CİHAZLAR']
# Lütfen okumak istediğiniz sayfanın adını girin:  2018-01 OTOKLAV
# 'df_otoklav_C:\Users\duygu\Desktop\00' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2018/001     2018-01-04
# 1                 DMO                        2018/072     2017-12-28
# 2                ÖZEL                        2018/071     2017-12-25
#
#                          SİPARİŞİ VEREN/2018  \
# 0  YENİ HAYAT TIP MERKEZİ-ORJİN SAĞLIK HİZM.
# 1                         DMO GENEL MÜDÜRLÜK
# 2                   BURSA RETİNA GÖZ MERKEZİ
#
#                                   KURULUM YERİ /2018        İL ÜRÜN MODELİ  \
# 0          YENİ HAYAT TIP MERKEZİ-ORJİN SAĞLIK HİZM.  İSTANBUL  STR 6610 D
# 1  T.C. GIDA TARIM VE HAYV. BAKANLIĞI GIDA VE KON...    ANKARA      7717 S
# 2                           BURSA RETİNA GÖZ MERKEZİ     BURSA  ERS 4410 D
#
#                                             ÜRÜN ADI       LİTRE      SERİ NO  \
# 0                  422 LT ÇİFT KAPILI OTOKLAV CİHAZI   422 LİTRE  2018/01-001
# 1  2000 LT ÇİFT KAPILI LABARATUVAR TİP BUHAR STER...  2000 LİTRE  2018/01-002
# 2                  160 LT ÇİFT KAPILI OTOKLAV CİHAZI   160 LİTRE  2018/01-003
#
#   TESLİM \nSÜRESİ TESLİM TARİHİ
# 0              30           NaT
# 1         100 GÜN    2018-04-06
# 2              20           NaT

# %% [markdown]
# ### Excel dosyayi CSV olarak bulundugun klasore kayit etme:

# %%
# save_and_load_csv() Fonksiyonunu cagirarak CSV olarak dosyayi bulundugunuz klasore kayit eder;

# Burada önce 01_OTOKLAV yazan yeri github da KATEGORI için olusturulan klasör adını veriniz.
notebook_dir = r"C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\01_EDA\DATA INCELEME\01_OTOKLAV"  # Kendi çalışma klasor yolunuz

# En son olusturulan DataFrame'i hem CSV olarak kaydet hem de tekrar oku (kendi kategorinize gore isimlendiriniz)
df_otoklav_18 = utils.save_and_load_csv('df_otoklav_18.csv', notebook_dir)  # Kayıt edeceğiniz adı yazın

# İlk birkaç satırı kontrol et
df_otoklav_18.head()
# Out:
# DataFrame başarıyla 'C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\01_EDA\DATA INCELEME\01_OTOKLAV\df_otoklav_18.csv' olarak kaydedildi.
# DataFrame başarıyla 'C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\01_EDA\DATA INCELEME\01_OTOKLAV\df_otoklav_18.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2018/001     2018-01-04
# 1                 DMO                        2018/072     2017-12-28
# 2                ÖZEL                        2018/071     2017-12-25
# 3            YURTDIŞI                        2018/064     2018-01-22
# 4                 DMO                        2018/107     2018-01-29
#
#                          SİPARİŞİ VEREN/2018  \
# 0  YENİ HAYAT TIP MERKEZİ-ORJİN SAĞLIK HİZM.
# 1                         DMO GENEL MÜDÜRLÜK
# 2                   BURSA RETİNA GÖZ MERKEZİ
# 3                            BAHRİ GROUP CO.
# 4               DMO İSTANBUL BÖLGE MÜDÜRLÜĞÜ
#
#                                   KURULUM YERİ /2018          İL ÜRÜN MODELİ  \
# 0          YENİ HAYAT TIP MERKEZİ-ORJİN SAĞLIK HİZM.    İSTANBUL  STR 6610 D
# 1  T.C. GIDA TARIM VE HAYV. BAKANLIĞI GIDA VE KON...      ANKARA      7717 S
# 2                           BURSA RETİNA GÖZ MERKEZİ       BURSA  ERS 4410 D
# 3                                    BAHRİ GROUP CO.  KUZEY IRAK    STR 75 V
# 4  HUDUT VE SAHİLLER GENEL MÜDÜRLÜĞÜ DESTEK HİZME...    İSTANBUL  ERS 6613 D
#
#                                             ÜRÜN ADI       LİTRE      SERİ NO  \
# 0                  422 LT ÇİFT KAPILI OTOKLAV CİHAZI   422 LİTRE  2018/01-001
# 1  2000 LT ÇİFT KAPILI LABARATUVAR TİP BUHAR STER...  2000 LİTRE  2018/01-002
# 2                  160 LT ÇİFT KAPILI OTOKLAV CİHAZI   160 LİTRE  2018/01-003
# 3                       75 LT VAKUMLU OTOKLAV CİHAZI       75 LT  2018/01-004
# 4            550 LT ÇİFT KAYAR KAPILI OTOKLAV CİHAZI      550 LT  2018/01-005
#
#   TESLİM \nSÜRESİ TESLİM TARİHİ
# 0              30           NaN
# 1         100 GÜN    2018-04-06
# 2              20           NaN
# 3              20           NaN
# 4              20           NaN

# %% [markdown]
# ## 2019 Otoklav

# %%
# Excel Dosyasini okuma:

df_otoklav_19 = utils.read_excel_page()
df_otoklav_19.head()
# Out:
# Lütfen Dataset dosya yolunu girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\00_Data\01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\00_Data\01_Satis_Uretim\2019-Uretim_Takip.xlsx
# Dosyadaki sayfa adları: ['2019-01 OTOKLAV', '2019-02-AMELİYAT MASASI', '2019-04-HİDROJEN PEROKSİT', '2019-05-YIKAMA', '2019-06-OKSİJEN SİSTEMİ', '2019-07-KARTUŞ', '2019-08-REVERSE OSMOS ']
# Lütfen okumak istediğiniz sayfanın adını girin: 2019-01 OTOKLAV
# 'df_otoklav_C:\Users\duygu\Desktop\00' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                 DMO                        2019/001     2019-03-15
# 1            YURTDIŞI                        2019/002     2019-01-02
# 2                ÖZEL                        2019/003     2019-01-10
# 3                ÖZEL                        2019/010     2019-01-28
# 4                 DMO                        2019/011     2019-02-19
#
#                         SİPARİŞİ VEREN/2018  \
# 0                DMO ELAZIĞ BÖLGE MÜDÜRLÜĞÜ
# 1           TSA SOLUCİONES MEDİCAS CİA LTDA
# 2                      GÖRSEL ÖZEL TIP LTD.
# 3  ER-PA ÖZEL DENİZLİ SAĞLIK HASTANESİ A.Ş.
# 4                       DMO GENEL MÜDÜRLÜĞÜ
#
#                          KURULUM YERİ /2018       İL     ÜRÜN MODELİ  \
# 0                 SU ŞEHRİ DEVLET HASTANESİ    SİVAS  GOLDBERG 550 D
# 1           TSA SOLUCİONES MEDİCAS CİA LTDA  EKVATOR      STR 5512 S
# 2                      GÖRSEL ÖZEL TIP LTD.   ANKARA      STR 4410 D
# 3  ER-PA ÖZEL DENİZLİ SAĞLIK HASTANESİ A.Ş.  DENİZLİ      STR 6613 D
# 4                ETİMESGUT DEVLET HASTANESİ   ANKARA      ERS 6613 D
#
#                                   ÜRÜN ADI   LİTRE      SERİ NO  \
# 0  550 LT ÇİFT KAYAR KAPILI OTOKLAV CİHAZI  550 LT  2019/01-012
# 1   300 LT TEK KAYAR KAPILI OTOKLAV CİHAZI  300 LT  2019/01-001
# 2  160 LT ÇİFT KAYAR KAPILI OTOKLAV CİHAZI  160 LT  2019/01-002
# 3  550 LT ÇİFT KAYAR KAPILI OTOKLAV CİHAZI  550 LT  2019/01-003
# 4  550 LT ÇİFT KAYAR KAPILI OTOKLAV CİHAZI  550 LT  2019/01-006
#
#   TESLİM \nSÜRESİ  TESLİM TARİHİ
# 0      2019-05-08            NaN
# 1      2019-01-28            NaN
# 2      2019-01-25            NaN
# 3      2019-02-11            NaN
# 4      2019-03-19            NaN

# %%
# DataFrame'i hem CSV olarak kaydet hem de tekrar oku

# Bulundugun Klasor yolu (bir kez tanimlamak yeterli)
notebook_dir = r"C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\01_EDA\DATA INCELEME\01_OTOKLAV"  # Kendi çalışma dizininizi belirtin

df_otoklav_19 = utils.save_and_load_csv('df_otoklav_19.csv', notebook_dir)
df_otoklav_19.head()
# Out:
# DataFrame başarıyla 'C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\01_EDA\DATA INCELEME\01_OTOKLAV\df_otoklav_19.csv' olarak kaydedildi.
# DataFrame başarıyla 'C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\01_EDA\DATA INCELEME\01_OTOKLAV\df_otoklav_19.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2018/001     2018-01-04
# 1                 DMO                        2018/072     2017-12-28
# 2                ÖZEL                        2018/071     2017-12-25
# 3            YURTDIŞI                        2018/064     2018-01-22
# 4                 DMO                        2018/107     2018-01-29
#
#                          SİPARİŞİ VEREN/2018  \
# 0  YENİ HAYAT TIP MERKEZİ-ORJİN SAĞLIK HİZM.
# 1                         DMO GENEL MÜDÜRLÜK
# 2                   BURSA RETİNA GÖZ MERKEZİ
# 3                            BAHRİ GROUP CO.
# 4               DMO İSTANBUL BÖLGE MÜDÜRLÜĞÜ
#
#                                   KURULUM YERİ /2018          İL ÜRÜN MODELİ  \
# 0          YENİ HAYAT TIP MERKEZİ-ORJİN SAĞLIK HİZM.    İSTANBUL  STR 6610 D
# 1  T.C. GIDA TARIM VE HAYV. BAKANLIĞI GIDA VE KON...      ANKARA      7717 S
# 2                           BURSA RETİNA GÖZ MERKEZİ       BURSA  ERS 4410 D
# 3                                    BAHRİ GROUP CO.  KUZEY IRAK    STR 75 V
# 4  HUDUT VE SAHİLLER GENEL MÜDÜRLÜĞÜ DESTEK HİZME...    İSTANBUL  ERS 6613 D
#
#                                             ÜRÜN ADI       LİTRE      SERİ NO  \
# 0                  422 LT ÇİFT KAPILI OTOKLAV CİHAZI   422 LİTRE  2018/01-001
# 1  2000 LT ÇİFT KAPILI LABARATUVAR TİP BUHAR STER...  2000 LİTRE  2018/01-002
# 2                  160 LT ÇİFT KAPILI OTOKLAV CİHAZI   160 LİTRE  2018/01-003
# 3                       75 LT VAKUMLU OTOKLAV CİHAZI       75 LT  2018/01-004
# 4            550 LT ÇİFT KAYAR KAPILI OTOKLAV CİHAZI      550 LT  2018/01-005
#
#   TESLİM \nSÜRESİ TESLİM TARİHİ
# 0              30           NaN
# 1         100 GÜN    2018-04-06
# 2              20           NaN
# 3              20           NaN
# 4              20           NaN

# %% [markdown]
# ## 2020 Otoklav

# %%
# Excel Dosyasini okuma:

df_otoklav_20 = utils.read_excel_page()
df_otoklav_20.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): 2020-Uretim_Takip.xlsx
# Dosyadaki sayfa adları: ['2020-01 OTOKLAV', '2020-02-AMELİYAT MASASI', '2020-04-HİDROJEN PEROKSİT', '2020-05-YIKAMA', '2020-06-OKSİJEN SİSTEMİ', '2020-07-KARTUŞ', '2020-08-REVERSE OSMOS ']
# Lütfen okumak istediğiniz sayfanın adını girin: 2020-01 OTOKLAV
# 'df_otoklav_2020' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO       SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2020/001  2019-12-17 00:00:00
# 1                ÖZEL                        2020/002  2019-12-17 00:00:00
# 2                ÖZEL                        2020/003  2019-12-17 00:00:00
# 3                ÖZEL                        2020/004  2019-12-17 00:00:00
# 4                ÖZEL                        2020/005  2019-12-17 00:00:00
#
#   SİPARİŞİ VEREN/2018 KURULUM YERİ /2018        İL     ÜRÜN MODELİ  \
# 0           ADAY GRUP           ETİYOPYA  ETİYOPYA  GOLDBERG 100 V
# 1           ADAY GRUP           ETİYOPYA  ETİYOPYA  GOLDBERG 100 V
# 2           ADAY GRUP           ETİYOPYA  ETİYOPYA  GOLDBERG 100 V
# 3           ADAY GRUP           ETİYOPYA  ETİYOPYA  GOLDBERG 100 V
# 4           ADAY GRUP           ETİYOPYA  ETİYOPYA  GOLDBERG 100 V
#
#                         ÜRÜN ADI   LİTRE      SERİ NO      TESLİM \nSÜRESİ  \
# 0  100 LT DİK TİP OTOKLAV CİHAZI  100 LT  2020/01-001  2020-02-01 00:00:00
# 1  100 LT DİK TİP OTOKLAV CİHAZI  100 LT  2020/01-002  2020-02-01 00:00:00
# 2  100 LT DİK TİP OTOKLAV CİHAZI  100 LT  2020/01-003  2020-02-01 00:00:00
# 3  100 LT DİK TİP OTOKLAV CİHAZI  100 LT  2020/01-004  2020-02-01 00:00:00
# 4  100 LT DİK TİP OTOKLAV CİHAZI  100 LT  2020/01-005  2020-02-01 00:00:00
#
#    TESLİM TARİHİ
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# DataFrame'i hem CSV olarak kaydet hem de tekrar oku

# 'notebook_dir' yolunu yukarida bir kez tanimladigimiz icin tekrar etmeye gerek yok, ayni klasorde calisiyoruz

df_otoklav_20 = utils.save_and_load_csv('df_otoklav_20.csv', notebook_dir)
df_otoklav_20.head()
# Out:
# DataFrame başarıyla 'C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\01_EDA\DATA INCELEME\01_OTOKLAV\df_otoklav_20.csv' olarak kaydedildi.
# DataFrame başarıyla 'C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\01_EDA\DATA INCELEME\01_OTOKLAV\df_otoklav_20.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2018/001     2018-01-04
# 1                 DMO                        2018/072     2017-12-28
# 2                ÖZEL                        2018/071     2017-12-25
# 3            YURTDIŞI                        2018/064     2018-01-22
# 4                 DMO                        2018/107     2018-01-29
#
#                          SİPARİŞİ VEREN/2018  \
# 0  YENİ HAYAT TIP MERKEZİ-ORJİN SAĞLIK HİZM.
# 1                         DMO GENEL MÜDÜRLÜK
# 2                   BURSA RETİNA GÖZ MERKEZİ
# 3                            BAHRİ GROUP CO.
# 4               DMO İSTANBUL BÖLGE MÜDÜRLÜĞÜ
#
#                                   KURULUM YERİ /2018          İL ÜRÜN MODELİ  \
# 0          YENİ HAYAT TIP MERKEZİ-ORJİN SAĞLIK HİZM.    İSTANBUL  STR 6610 D
# 1  T.C. GIDA TARIM VE HAYV. BAKANLIĞI GIDA VE KON...      ANKARA      7717 S
# 2                           BURSA RETİNA GÖZ MERKEZİ       BURSA  ERS 4410 D
# 3                                    BAHRİ GROUP CO.  KUZEY IRAK    STR 75 V
# 4  HUDUT VE SAHİLLER GENEL MÜDÜRLÜĞÜ DESTEK HİZME...    İSTANBUL  ERS 6613 D
#
#                                             ÜRÜN ADI       LİTRE      SERİ NO  \
# 0                  422 LT ÇİFT KAPILI OTOKLAV CİHAZI   422 LİTRE  2018/01-001
# 1  2000 LT ÇİFT KAPILI LABARATUVAR TİP BUHAR STER...  2000 LİTRE  2018/01-002
# 2                  160 LT ÇİFT KAPILI OTOKLAV CİHAZI   160 LİTRE  2018/01-003
# 3                       75 LT VAKUMLU OTOKLAV CİHAZI       75 LT  2018/01-004
# 4            550 LT ÇİFT KAYAR KAPILI OTOKLAV CİHAZI      550 LT  2018/01-005
#
#   TESLİM \nSÜRESİ TESLİM TARİHİ
# 0              30           NaN
# 1         100 GÜN    2018-04-06
# 2              20           NaN
# 3              20           NaN
# 4              20           NaN

# %% [markdown]
# ## 2021 Otoklav

# %%
# Excel Okuma, df olusturma

df_otoklav_21 = utils.read_excel_page()
df_otoklav_21.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): 2021-Uretim_Takip.xlsx
# Dosyadaki sayfa adları: ['2021-01 OTOKLAV', '2021-02-AMELİYAT MASASI', '2021-04-HİDROJEN PEROKSİT', '2021-05-YIKAMA', '2021-06-OKSİJEN', '2021-07-KARTUŞ', '2021-08-REVERSE OSMOS ']
# Lütfen okumak istediğiniz sayfanın adını girin: 2021-01 OTOKLAV
# 'df_otoklav_2021' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2020/496     2020-12-25
# 1                ÖZEL                        2021/015     2020-12-25
# 2                ÖZEL                        2019/243     2020-12-22
# 3            YURTDIŞI                        2021/003     2021-09-10
# 4                ÖZEL                        2021/006     2021-11-11
#
#                               SİPARİŞİ VEREN/2021  \
# 0       SAMSUN MEDİKAL GRUP ÖZEL SAĞLIK HİZM.A.Ş.
# 1       SAMSUN MEDİKAL GRUP ÖZEL SAĞLIK HİZM.A.Ş.
# 2                     DMO TRABZON BÖLGE MÜDÜRLÜĞÜ
# 3                                         ROMANYA
# 4  ÖZEL SEYGÖL AİLE SAĞLIK HİZM.İLAÇ SAN.TİC.A.Ş.
#
#                              KURULUM YERİ /2021        İL ÜRÜN MODELİ  \
# 0                 MLPCARE VADİ İSTANBUL PROJESİ  İSTANBUL  STR 6613 D
# 1                 MLPCARE VADİ İSTANBUL PROJESİ  İSTANBUL  STR 6613 D
# 2  GİRESUN ÜNİVERSİTESİ DİŞ HEKİMLİĞİ FAKÜLTESİ   GİRESUN  ERS 5512 D
# 3                                       ROMANYA   ROMANYA  STR 5512 D
# 4                     İZMİT CERRAHİ TIP MERKEZİ   KOCAELİ  STR 5512 D
#
#                             ÜRÜN ADI   LİTRE      SERİ NO  \
# 0  550 LT ÇİFT KAPILI OTOKLAV CİHAZI  550 LT  2021/01-001
# 1  550 LT ÇİFT KAPILI OTOKLAV CİHAZI  550 LT  2021/01-002
# 2  300 LT ÇİFT KAPILI OTOKLAV CİHAZI  300 LT  2021/01-003
# 3  300 LT ÇİFT KAPILI OTOKLAV CİHAZI  300 LT  2021/01-090
# 4  300 LT ÇİFT KAPILI OTOKLAV CİHAZI  300 LT  2021/01-013
#
#        TESLİM \nSÜRESİ  TESLİM TARİHİ  Teslim Süresi
# 0  2021-03-01 00:00:00            NaN           66.0
# 1  2021-03-01 00:00:00            NaN           66.0
# 2  2021-02-19 00:00:00            NaN           59.0
# 3  2021-10-15 00:00:00            NaN           35.0
# 4  2021-11-18 00:00:00            NaN            7.0

# %%
# df olarak save and Load:

df_otoklav_21 = save_and_load_csv('df_otoklav_21.csv', notebook_dir) 
df_otoklav_21.head()
# Out:
# DataFrame başarıyla 'C:\Users\ASUS\Desktop\INT_1_PROJECT\01_EDA\01_OTOKLAV\df_otoklav_21.csv' olarak kaydedildi.
# DataFrame başarıyla 'C:\Users\ASUS\Desktop\INT_1_PROJECT\01_EDA\01_OTOKLAV\df_otoklav_21.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2020/496     2020-12-25
# 1                ÖZEL                        2021/015     2020-12-25
# 2                ÖZEL                        2019/243     2020-12-22
# 3            YURTDIŞI                        2021/003     2021-09-10
# 4                ÖZEL                        2021/006     2021-11-11
#
#                               SİPARİŞİ VEREN/2021  \
# 0       SAMSUN MEDİKAL GRUP ÖZEL SAĞLIK HİZM.A.Ş.
# 1       SAMSUN MEDİKAL GRUP ÖZEL SAĞLIK HİZM.A.Ş.
# 2                     DMO TRABZON BÖLGE MÜDÜRLÜĞÜ
# 3                                         ROMANYA
# 4  ÖZEL SEYGÖL AİLE SAĞLIK HİZM.İLAÇ SAN.TİC.A.Ş.
#
#                              KURULUM YERİ /2021        İL ÜRÜN MODELİ  \
# 0                 MLPCARE VADİ İSTANBUL PROJESİ  İSTANBUL  STR 6613 D
# 1                 MLPCARE VADİ İSTANBUL PROJESİ  İSTANBUL  STR 6613 D
# 2  GİRESUN ÜNİVERSİTESİ DİŞ HEKİMLİĞİ FAKÜLTESİ   GİRESUN  ERS 5512 D
# 3                                       ROMANYA   ROMANYA  STR 5512 D
# 4                     İZMİT CERRAHİ TIP MERKEZİ   KOCAELİ  STR 5512 D
#
#                             ÜRÜN ADI   LİTRE      SERİ NO  \
# 0  550 LT ÇİFT KAPILI OTOKLAV CİHAZI  550 LT  2021/01-001
# 1  550 LT ÇİFT KAPILI OTOKLAV CİHAZI  550 LT  2021/01-002
# 2  300 LT ÇİFT KAPILI OTOKLAV CİHAZI  300 LT  2021/01-003
# 3  300 LT ÇİFT KAPILI OTOKLAV CİHAZI  300 LT  2021/01-090
# 4  300 LT ÇİFT KAPILI OTOKLAV CİHAZI  300 LT  2021/01-013
#
#        TESLİM \nSÜRESİ  TESLİM TARİHİ  Teslim Süresi
# 0  2021-03-01 00:00:00            NaN           66.0
# 1  2021-03-01 00:00:00            NaN           66.0
# 2  2021-02-19 00:00:00            NaN           59.0
# 3  2021-10-15 00:00:00            NaN           35.0
# 4  2021-11-18 00:00:00            NaN            7.0

# %% [markdown]
# ## 2022 Otoklav

# %%
# Excel dosyasini read and df

df_otoklav_22 = utils.read_excel_page()
df_otoklav_22.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): 2022-Uretim_Takip.xlsx
# Dosyadaki sayfa adları: ['2022-01 OTOKLAV', '2022-02 AMELİYAT MASASI', '2022-04 HİDROJEN PEROSİT-PLAZMA', '2022-05 YIKAMA', '2022-06 OKSİJEN', '2022-07 KARTUŞ', '2022-08 REVERSE OSMOS']
# Lütfen okumak istediğiniz sayfanın adını girin: 2022-01 OTOKLAV
# 'df_otoklav_2022' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2019/326     2022-11-09
# 1            YURTDIŞI                        2021/020     2022-04-13
# 2    2024 e aktarıldı                        2022/001     2022-01-06
# 3    2024 e aktarıldı                        2022/002     2023-02-15
# 4    2024 e aktarıldı                        2022/003     2022-01-06
#
#                                  SİPARİŞİ VEREN/2022  \
# 0  İNNOMED LABORATUVAR İTH. İHR. SAN. TİC. LTD. ŞTİ.
# 1                                              KONGO
# 2                                   2024 e aktarıldı
# 3                                   2024 e aktarıldı
# 4                                   2024 e aktarıldı
#
#                                   KURULUM YERİ /2022        İL  \
# 0  İNNOMED LABORATUVAR İTH. İHR. SAN. TİC. LTD. ŞTİ.  İSTANBUL
# 1                                              KONGO     KONGO
# 2                                   2024 e aktarıldı      STOK
# 3                                   2024 e aktarıldı      STOK
# 4                                   2024 e aktarıldı      STOK
#
#                ÜRÜN MODELİ                                ÜRÜN ADI   LİTRE  \
# 0           GOLDBERG 250 S  250 LT TEK KAYAR KAPILI OTOKLAV CİHAZI  250 LT
# 1  GOLDBERG 840 D-REVİZYON       840 LT ÇİFT KAPILI OTOKLAV CİHAZI  840 LT
# 2                      NaN            75 LT DİK TİP OTOKLAV CİHAZI   75 LT
# 3                      NaN            75 LT DİK TİP OTOKLAV CİHAZI   75 LT
# 4                      NaN            75 LT DİK TİP OTOKLAV CİHAZI   75 LT
#
#        SERİ NO TESLİM SÜRESİ TESLİM \nTARİHİ İRSALİYE TARİHİ
# 0  2022/01-164           NaN      2022-12-09             NaN
# 1  2022/01-036           NaN      2022-05-04             NaN
# 2          NaN           NaN             NaT             NaN
# 3          NaN           NaN             NaT             NaN
# 4          NaN           NaN             NaT             NaN

# %%
# # df olarak save and Load:

df_otoklav_22 = utils.save_and_load_csv('df_otoklav_22.csv', notebook_dir) #kayıt edeceğiniz adı yazın.
df_otoklav_22.head()
# Out:
# DataFrame başarıyla 'C:\Users\ASUS\Desktop\INT_1_PROJECT\01_EDA\01_OTOKLAV\df_otoklav_22.csv' olarak kaydedildi.
# DataFrame başarıyla 'C:\Users\ASUS\Desktop\INT_1_PROJECT\01_EDA\01_OTOKLAV\df_otoklav_22.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2019/326     2022-11-09
# 1            YURTDIŞI                        2021/020     2022-04-13
# 2    2024 e aktarıldı                        2022/001     2022-01-06
# 3    2024 e aktarıldı                        2022/002     2023-02-15
# 4    2024 e aktarıldı                        2022/003     2022-01-06
#
#                                  SİPARİŞİ VEREN/2022  \
# 0  İNNOMED LABORATUVAR İTH. İHR. SAN. TİC. LTD. ŞTİ.
# 1                                              KONGO
# 2                                   2024 e aktarıldı
# 3                                   2024 e aktarıldı
# 4                                   2024 e aktarıldı
#
#                                   KURULUM YERİ /2022        İL  \
# 0  İNNOMED LABORATUVAR İTH. İHR. SAN. TİC. LTD. ŞTİ.  İSTANBUL
# 1                                              KONGO     KONGO
# 2                                   2024 e aktarıldı      STOK
# 3                                   2024 e aktarıldı      STOK
# 4                                   2024 e aktarıldı      STOK
#
#                ÜRÜN MODELİ                                ÜRÜN ADI   LİTRE  \
# 0           GOLDBERG 250 S  250 LT TEK KAYAR KAPILI OTOKLAV CİHAZI  250 LT
# 1  GOLDBERG 840 D-REVİZYON       840 LT ÇİFT KAPILI OTOKLAV CİHAZI  840 LT
# 2                      NaN            75 LT DİK TİP OTOKLAV CİHAZI   75 LT
# 3                      NaN            75 LT DİK TİP OTOKLAV CİHAZI   75 LT
# 4                      NaN            75 LT DİK TİP OTOKLAV CİHAZI   75 LT
#
#        SERİ NO TESLİM SÜRESİ TESLİM \nTARİHİ İRSALİYE TARİHİ
# 0  2022/01-164           NaN      2022-12-09             NaN
# 1  2022/01-036           NaN      2022-05-04             NaN
# 2          NaN           NaN             NaN             NaN
# 3          NaN           NaN             NaN             NaN
# 4          NaN           NaN             NaN             NaN

# %% [markdown]
# ## 2023 Otoklav

# %%
# Excel Dosyasini okuma:

df_otoklav_23 = utils.read_excel_page()
df_otoklav_23.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): 2023-Uretim_Takip.xlsx
# Dosyadaki sayfa adları: ['LİSTE', '2023-01 OTOKLAV', '2023-02 AMELİYAT MASASI', '2023-03 JİNEKOLOJİK MUAYENE', '2023-04 HİDROJEN PEROSİT-PLAZMA', '2023-05 YIKAMA', '2023-06 OKSİJEN', '2023-07 KARTUŞ', '2023-08 REVERSE OSMOS', '2023-09 ULTRASONİK YIKAMA', '2023-10 KAPAMA CİHAZI', '2023-11 DİĞER CİHAZLAR', 'DEMO GİDEN CİHAZLAR', 'Sayfa1']
# Lütfen okumak istediğiniz sayfanın adını girin: 2023-01 OTOKLAV
# 'df_otoklav_2023' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2021/278     2023-09-14
# 1            YURTDIŞI                        2021/388     2023-08-14
# 2            YURTDIŞI                        2022/018     2023-07-31
# 3            YURTDIŞI                        2022/019     2023-03-20
# 4            YURTDIŞI                        2022/020     2023-07-31
#
#                                  SİPARİŞİ VEREN/2023  \
# 0  ÖZEL KIZILTEPE SAĞLIK HİZMETLERİ SAN. VE TİC. ...
# 1                                               IRAK
# 2                                            ROMANYA
# 3                                            UKRAYNA
# 4                                            ROMANYA
#
#                   KURULUM YERİ /2023       İL ÜRÜN MODELİ  \
# 0  ÖZEL KIZILTEPE İPEKYOLU HASTANESİ   MARDİN  STR 5510 D
# 1                               IRAK     IRAK  STR 4410 S
# 2                            ROMANYA  ROMANYA  STR 4407 S
# 3                            UKRAYNA  UKRAYNA  STR 4407 S
# 4                            ROMANYA  ROMANYA  STR 4407 S
#
#                            ÜRÜN ADI   LİTRE      SERİ NO  \
# 0  250 LT ÇİFT KAPILI OTOKAV CİHAZI  250 LT  2023/01-101
# 1  160 LT TEK KAPILI OTOKLAV CİHAZI  160 LT  2023/01-096
# 2  120 LT TEK KAPILI OTOKLAV CİHAZI  120 LT  2023/01-089
# 3  120 LT TEK KAPILI OTOKLAV CİHAZI  120 LT  2023/01-042
# 4  120 LT TEK KAPILI OTOKLAV CİHAZI  120 LT  2023/01-090
#
#                    TESLİM SÜRESİ TESLİM \nTARİHİ İRSALİYE TARİHİ
# 0                            NaN      2023-09-21             NaN
# 1                            NaN      2023-08-16             NaN
# 2                            NaN      2023-09-05             NaN
# 3  SİPARİŞ GELMEDEN DOSYA AÇILDI      2023-04-19             NaN
# 4                            NaN      2023-09-05             NaN

# %%
# df olarak save and Load:

df_otoklav_23 = utils.save_and_load_csv(df_otoklav_23, 'df_otoklav_23.csv', notebook_dir)
df_otoklav_23.head()
# Out:
# DataFrame başarıyla 'C:\Users\ASUS\Desktop\INT_1_PROJECT\01_EDA\01_OTOKLAV\df_otoklav_23.csv' olarak kaydedildi.
# DataFrame başarıyla 'C:\Users\ASUS\Desktop\INT_1_PROJECT\01_EDA\01_OTOKLAV\df_otoklav_23.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2021/278     2023-09-14
# 1            YURTDIŞI                        2021/388     2023-08-14
# 2            YURTDIŞI                        2022/018     2023-07-31
# 3            YURTDIŞI                        2022/019     2023-03-20
# 4            YURTDIŞI                        2022/020     2023-07-31
#
#                                  SİPARİŞİ VEREN/2023  \
# 0  ÖZEL KIZILTEPE SAĞLIK HİZMETLERİ SAN. VE TİC. ...
# 1                                               IRAK
# 2                                            ROMANYA
# 3                                            UKRAYNA
# 4                                            ROMANYA
#
#                   KURULUM YERİ /2023       İL ÜRÜN MODELİ  \
# 0  ÖZEL KIZILTEPE İPEKYOLU HASTANESİ   MARDİN  STR 5510 D
# 1                               IRAK     IRAK  STR 4410 S
# 2                            ROMANYA  ROMANYA  STR 4407 S
# 3                            UKRAYNA  UKRAYNA  STR 4407 S
# 4                            ROMANYA  ROMANYA  STR 4407 S
#
#                            ÜRÜN ADI   LİTRE      SERİ NO  \
# 0  250 LT ÇİFT KAPILI OTOKAV CİHAZI  250 LT  2023/01-101
# 1  160 LT TEK KAPILI OTOKLAV CİHAZI  160 LT  2023/01-096
# 2  120 LT TEK KAPILI OTOKLAV CİHAZI  120 LT  2023/01-089
# 3  120 LT TEK KAPILI OTOKLAV CİHAZI  120 LT  2023/01-042
# 4  120 LT TEK KAPILI OTOKLAV CİHAZI  120 LT  2023/01-090
#
#                    TESLİM SÜRESİ TESLİM \nTARİHİ İRSALİYE TARİHİ
# 0                            NaN      2023-09-21             NaN
# 1                            NaN      2023-08-16             NaN
# 2                            NaN      2023-09-05             NaN
# 3  SİPARİŞ GELMEDEN DOSYA AÇILDI      2023-04-19             NaN
# 4                            NaN      2023-09-05             NaN

# %% [markdown]
# ## 2023 Otoklav Endustriyel

# %%
# Excel Dosyasini okuma:

df_otoklav_23_Endust = utils.read_excel_page()
df_otoklav_23_Endust.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): 2023-Uretim_Takip-Endutriyel.xlsx
# Dosyadaki sayfa adları: ['2023-01 OTOKLAV', '2023-02 AMELİYAT MASASI', '2023-04 HİDROJEN PEROSİT-PLAZMA', '2023-05 YIKAMA', '2023-06 OKSİJEN', '2023-07 KARTUŞ', '2023-08 REVERSE OSMOS']
# Lütfen okumak istediğiniz sayfanın adını girin: 2023-01 OTOKLAV
# 'df_otoklav_2023' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2021/278     2023-09-14
# 1            YURTDIŞI                        2021/388     2023-08-14
# 2            YURTDIŞI                        2022/018     2023-07-31
# 3            YURTDIŞI                        2022/019     2023-03-20
# 4            YURTDIŞI                        2022/020     2023-07-31
#
#                                  SİPARİŞİ VEREN/2023  \
# 0  ÖZEL KIZILTEPE SAĞLIK HİZMETLERİ SAN. VE TİC. ...
# 1                                               IRAK
# 2                                            ROMANYA
# 3                                            UKRAYNA
# 4                                            ROMANYA
#
#                   KURULUM YERİ /2023       İL ÜRÜN MODELİ  \
# 0  ÖZEL KIZILTEPE İPEKYOLU HASTANESİ   MARDİN  STR 5510 D
# 1                               IRAK     IRAK  STR 4410 S
# 2                            ROMANYA  ROMANYA  STR 4407 S
# 3                            UKRAYNA  UKRAYNA  STR 4407 S
# 4                            ROMANYA  ROMANYA  STR 4407 S
#
#                            ÜRÜN ADI   LİTRE      SERİ NO TESLİM SÜRESİ  \
# 0  250 LT ÇİFT KAPILI OTOKAV CİHAZI  250 LT  2023/01-101        30 GÜN
# 1  160 LT TEK KAPILI OTOKLAV CİHAZI  160 LT  2023/01-096        30 GÜN
# 2  120 LT TEK KAPILI OTOKLAV CİHAZI  120 LT  2023/01-089        30 GÜN
# 3  120 LT TEK KAPILI OTOKLAV CİHAZI  120 LT  2023/01-042        30 GÜN
# 4  120 LT TEK KAPILI OTOKLAV CİHAZI  120 LT  2023/01-090        30 GÜN
#
#   TESLİM \nTARİHİ İRSALİYE TARİHİ
# 0      2023-09-21             NaN
# 1      2023-08-16             NaN
# 2      2023-09-05             NaN
# 3      2023-04-19             NaN
# 4      2023-09-05             NaN

# %%
# df olarak save and Load:

df_otoklav_23_Endust = utils.save_and_load_csv('df_otoklav_23_Endust.csv', notebook_dir)
df_otoklav_23_Endust.head()
# Out:
# DataFrame başarıyla 'C:\Users\ASUS\Desktop\INT_1_PROJECT\01_EDA\01_OTOKLAV\df_otoklav_23_Endust.csv' olarak kaydedildi.
# DataFrame başarıyla 'C:\Users\ASUS\Desktop\INT_1_PROJECT\01_EDA\01_OTOKLAV\df_otoklav_23_Endust.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2021/278     2023-09-14
# 1            YURTDIŞI                        2021/388     2023-08-14
# 2            YURTDIŞI                        2022/018     2023-07-31
# 3            YURTDIŞI                        2022/019     2023-03-20
# 4            YURTDIŞI                        2022/020     2023-07-31
#
#                                  SİPARİŞİ VEREN/2023  \
# 0  ÖZEL KIZILTEPE SAĞLIK HİZMETLERİ SAN. VE TİC. ...
# 1                                               IRAK
# 2                                            ROMANYA
# 3                                            UKRAYNA
# 4                                            ROMANYA
#
#                   KURULUM YERİ /2023       İL ÜRÜN MODELİ  \
# 0  ÖZEL KIZILTEPE İPEKYOLU HASTANESİ   MARDİN  STR 5510 D
# 1                               IRAK     IRAK  STR 4410 S
# 2                            ROMANYA  ROMANYA  STR 4407 S
# 3                            UKRAYNA  UKRAYNA  STR 4407 S
# 4                            ROMANYA  ROMANYA  STR 4407 S
#
#                            ÜRÜN ADI   LİTRE      SERİ NO TESLİM SÜRESİ  \
# 0  250 LT ÇİFT KAPILI OTOKAV CİHAZI  250 LT  2023/01-101        30 GÜN
# 1  160 LT TEK KAPILI OTOKLAV CİHAZI  160 LT  2023/01-096        30 GÜN
# 2  120 LT TEK KAPILI OTOKLAV CİHAZI  120 LT  2023/01-089        30 GÜN
# 3  120 LT TEK KAPILI OTOKLAV CİHAZI  120 LT  2023/01-042        30 GÜN
# 4  120 LT TEK KAPILI OTOKLAV CİHAZI  120 LT  2023/01-090        30 GÜN
#
#   TESLİM \nTARİHİ İRSALİYE TARİHİ
# 0      2023-09-21             NaN
# 1      2023-08-16             NaN
# 2      2023-09-05             NaN
# 3      2023-04-19             NaN
# 4      2023-09-05             NaN

# %% [markdown]
# ## 2024 Otoklav-Uretim

# %%
# Excel Dosyasini okuma:

df_otoklav_24 = utils.read_excel_page()
df_otoklav_24.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): 2024-Uretim_Takip.xlsx
# Dosyadaki sayfa adları: ['2024-01 OTOKLAV', '2024-02 AMELİYAT MASASI', '2024-04 HİDROJEN PEROSİT-PLAZMA', '2024-05 YIKAMA', '2024-06 OKSİJEN', '2024-07 KARTUŞ', '2024-08 REVERSE OSMOS']
# Lütfen okumak istediğiniz sayfanın adını girin: 2024-01 OTOKLAV
# 'df_otoklav_2024' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2022/485     2024-02-05
# 1            YURTDIŞI                        2022/486     2024-02-05
# 2            YURTDIŞI                        2022/514     2024-04-05
# 3                 DMO                        2023/366     2024-02-26
# 4                 DMO                        2023/354     2024-03-07
#
#                                 SİPARİŞİ VEREN/2024  \
# 0                                           UKRAYNA
# 1                                           UKRAYNA
# 2                   SANCAKTEPE ÖZEL BÖLGE HASTANESİ
# 3  DMO 1 NOLU OPERASYONEL SÜREÇLER DAİRE BAŞKANLIĞI
# 4                         DMO MERSİN İRTİBAT BÜROSU
#
#                                   KURULUM YERİ /2024        İL  \
# 0                                            UKRAYNA   UKRAYNA
# 1                                            UKRAYNA   UKRAYNA
# 2                    SANCAKTEPE ÖZEL BÖLGE HASTANESİ  İSTANBUL
# 3  ANKARA GÖLBAŞI ÜLKÜ ULUSOY AĞIZ VE DİŞ SAĞLIĞI...    ANKARA
# 4                          ADANA İL SAĞLIK MÜDÜRLÜĞÜ     ADANA
#
#       ÜRÜN MODELİ                            ÜRÜN ADI   LİTRE      SERİ NO  \
# 0  GOLDBERG 160 S    160 LT TEK KAPILI OTOKLAV CİHAZI  160 LT  2024/01-022
# 1  GOLDBERG 160 S    160 LT TEK KAPILI OTOKLAV CİHAZI  160 LT  2024/01-023
# 2      STR 7712 D   675 LT ÇİFT KAPILI OTOKLAV CİHAZI  675 LT  2024/01-076
# 3      ERS 5512 D  300 LT ÇİFT  KAPILI OTOKLAV CİHAZI  300 LT  2023/01-103
# 4      ERS 6613 D   550 LT ÇİFT KAPILI OTOKLAV CİHAZI  550 LT  2024/01-005
#
#   TESLİM SÜRESİ TESLİM \nTARİHİ İRSALİYE TARİHİ
# 0        30 GÜN      2024-03-15             NaN
# 1        30 GÜN      2024-03-15             NaN
# 2        30 GÜN      2024-04-15             NaN
# 3        65 GÜN      2024-05-01             NaN
# 4        65 GÜN      2024-05-11             NaN

# %%
# df olarak save and Load:

df_otoklav_24 = utils.save_and_load_csv('df_otoklav_24.csv', notebook_dir) 
df_otoklav_24.head()
# Out:
# DataFrame başarıyla 'C:\Users\ASUS\Desktop\INT_1_PROJECT\01_EDA\01_OTOKLAV\df_otoklav_24.csv' olarak kaydedildi.
# DataFrame başarıyla 'C:\Users\ASUS\Desktop\INT_1_PROJECT\01_EDA\01_OTOKLAV\df_otoklav_24.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2022/485     2024-02-05
# 1            YURTDIŞI                        2022/486     2024-02-05
# 2            YURTDIŞI                        2022/514     2024-04-05
# 3                 DMO                        2023/366     2024-02-26
# 4                 DMO                        2023/354     2024-03-07
#
#                                 SİPARİŞİ VEREN/2024  \
# 0                                           UKRAYNA
# 1                                           UKRAYNA
# 2                   SANCAKTEPE ÖZEL BÖLGE HASTANESİ
# 3  DMO 1 NOLU OPERASYONEL SÜREÇLER DAİRE BAŞKANLIĞI
# 4                         DMO MERSİN İRTİBAT BÜROSU
#
#                                   KURULUM YERİ /2024        İL  \
# 0                                            UKRAYNA   UKRAYNA
# 1                                            UKRAYNA   UKRAYNA
# 2                    SANCAKTEPE ÖZEL BÖLGE HASTANESİ  İSTANBUL
# 3  ANKARA GÖLBAŞI ÜLKÜ ULUSOY AĞIZ VE DİŞ SAĞLIĞI...    ANKARA
# 4                          ADANA İL SAĞLIK MÜDÜRLÜĞÜ     ADANA
#
#       ÜRÜN MODELİ                            ÜRÜN ADI   LİTRE      SERİ NO  \
# 0  GOLDBERG 160 S    160 LT TEK KAPILI OTOKLAV CİHAZI  160 LT  2024/01-022
# 1  GOLDBERG 160 S    160 LT TEK KAPILI OTOKLAV CİHAZI  160 LT  2024/01-023
# 2      STR 7712 D   675 LT ÇİFT KAPILI OTOKLAV CİHAZI  675 LT  2024/01-076
# 3      ERS 5512 D  300 LT ÇİFT  KAPILI OTOKLAV CİHAZI  300 LT  2023/01-103
# 4      ERS 6613 D   550 LT ÇİFT KAPILI OTOKLAV CİHAZI  550 LT  2024/01-005
#
#   TESLİM SÜRESİ TESLİM \nTARİHİ İRSALİYE TARİHİ
# 0        30 GÜN      2024-03-15             NaN
# 1        30 GÜN      2024-03-15             NaN
# 2        30 GÜN      2024-04-15             NaN
# 3        65 GÜN      2024-05-01             NaN
# 4        65 GÜN      2024-05-11             NaN

# %% [markdown]
# ## 2024 Otoklav Satis

# %%
# Excel Dosyasini okuma:

df_otoklav_24_satis = utils.read_excel_page()
df_otoklav_24_satis.head()
# Out:
# Lütfen Dataset dosya yolunu girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\00_Data\01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\00_Data\01_Satis_Uretim\2024-Satis_Analiz.xlsx
# Dosyadaki sayfa adları: ['otoklav', 'Yıkama', 'Hidrojen Peroksit', 'Oksijen', 'Reverse Osmoz', 'Ameliyat Masası']
# Lütfen okumak istediğiniz sayfanın adını girin: otoklav
# 'df_otoklav_C:\Users\duygu\Desktop\00' olarak kaydedildi.
#    Sıra No Modeller Satış Fiyatı (Dolar) Satış Fiyatı (Dolar).1
# 0      NaN      ERS              Yurtiçi               Yurtdışı
# 1      1.0       75                 7500                   9000
# 2      2.0      75V                 7500                   9000
# 3      3.0        -                 8400                  10000
# 4      4.0      NaN                 8400                  10000

# %%
# df olarak save and Load:

df_otoklav_24_satis = utils.save_and_load_csv('df_otoklav_24_satis.csv', notebook_dir) 
df_otoklav_24_satis.head()
# Out:
# DataFrame başarıyla 'C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\01_EDA\DATA INCELEME\01_OTOKLAV\df_otoklav_24_satis.csv' olarak kaydedildi.
# DataFrame başarıyla 'C:\Users\duygu\Desktop\00-GitHub-Repo\00-1INTERNSHIP\INT1_PROJECT\01_EDA\DATA INCELEME\01_OTOKLAV\df_otoklav_24_satis.csv' dosyasından okundu.
#    Sıra No Modeller Satış Fiyatı (Dolar) Satış Fiyatı (Dolar).1
# 0      NaN      ERS              Yurtiçi               Yurtdışı
# 1      1.0       75                 7500                   9000
# 2      2.0      75V                 7500                   9000
# 3      3.0        -                 8400                  10000
# 4      4.0      NaN                 8400                  10000
