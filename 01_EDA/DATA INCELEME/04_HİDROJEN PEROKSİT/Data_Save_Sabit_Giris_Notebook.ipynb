# %% [markdown]
# **Bu Dosya sadece dosya yollarından kendi kategorimize ulaşmayı ve o kategoriyi yıl bazında csv dosyası kayıt etmeyi içerir.Bu işlemi yaptıktan sonra çalışmalarınıza ayrı notebook da herzamanki işlemler ile devam edebilirsiniz.**
#
#
# -1. Dosyaların sadece yolunu kullanarak okuyacağız. Bunun için daha önce gönderilen videoya bakalım.
#
# -2. Sürekli bu işlemi yapmamak için aldığımız sayfayı csv dosyası olarak kayıt edeceğiz. Burada dikkat edilmesi gereken nokta çalışılan notebook ve exel aynı klasörde değil o yüzden dosya yollarını alarak devam ediyoruz. Dosya yollarının sizinki ile aynı olmasına dikkat edilmeli.
#
# - Sadece 2 farklı fonksiyon var. (Dosyanın kalabalık olması her dosyaya bu fonksiyonları uyguladığım için )
#
# Eğer takılırsanız lütfen bana ulaşın ya da watsapdan yazalım :) Fatma Nur A.

# %% [markdown]
# # <font color= #FF0000> <b> Data Review</b><font color= #FF0000>

# %%
import os
import pandas as pd

def read_excel_page():
    # 1. Kullanıcıdan çalışma dizinini alma
    base_dir = input("Lütfen çalışma dizinini girin (örnek: C:\\Users\\ASUS\\Desktop\\INT_1_PROJECT\\00_Data\\01_Satis_Uretim): ")
    os.chdir(base_dir)  # Çalışma dizinini ayarla
    
    # 2. Kullanıcıdan dosya adını alma
    file_name = input("Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): ")
    
    try:
        # 3. Dosyadaki tüm sayfa adlarını listeleme
        xls = pd.ExcelFile(file_name)
        sheet_names = xls.sheet_names
        print(f"Dosyadaki sayfa adları: {sheet_names}")
        
        # 4. Kullanıcıdan sayfa adını seçmesini isteme
        selected_page = input("Lütfen okumak istediğiniz sayfanın adını girin: ")

        # 5. Seçilen sayfayı DataFrame olarak alma
        if selected_page in sheet_names:
            df = pd.read_excel(file_name, sheet_name=selected_page)
            
            # 6. Boş sütunları kaldırma
            df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
            
            # 7. Dinamik DataFrame adı oluşturma
            df_name = f"df_otoklav_{file_name.split('-')[0]}"
            
            # 8. DataFrame'i döndürme ve adıyla birlikte yazdırma
            globals()[df_name] = df  # Global değişken olarak atama
            print(f"'{df_name}' olarak kaydedildi.")
            return df

        else:
            print("Geçersiz sayfa adı. Lütfen doğru sayfa adını girin.")

    except FileNotFoundError:
        print("Dosya bulunamadı. Lütfen dosya adını doğru girdiğinizden emin olun.")
    except Exception as e:
        print(f"Hata: {e}")

# %%
import os
import pandas as pd

def save_and_load_csv(df, filename, dir_path):
    """
    DataFrame'i belirtilen dizine CSV olarak kaydeder ve tekrar yükler.
    
    Args:
    - df (DataFrame): Kaydedilecek DataFrame.
    - filename (str): Kaydedilecek dosya adı (örnek: 'df_otoklav_18.csv').
    - dir_path (str): Dosyanın kaydedileceği dizin.
    
    Returns:
    - loaded_df (DataFrame): Yüklenen DataFrame.
    """
    # 1. Tam dosya yolunu oluşturma
    csv_file_path = os.path.join(dir_path, filename)

    # 2. DataFrame'i CSV dosyası olarak kaydetme
    df.to_csv(csv_file_path, index=False)
    print(f"DataFrame başarıyla '{csv_file_path}' olarak kaydedildi.")

    # 3. Kaydedilen CSV dosyasını okuma
    loaded_df = pd.read_csv(csv_file_path)
    print(f"DataFrame başarıyla '{csv_file_path}' dosyasından okundu.")

    return loaded_df

# %%
df_hidrojen_peroksit_18 = read_excel_page()
df_hidrojen_peroksit_18.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2018-Uretim_Takip.xlsx
# Dosyadaki sayfa adları: ['2018-01 OTOKLAV', '2018-02-AMELİYAT MASASI', '2018-04-HİDROJEN PEROKSİT', '2018-05-YIKAMA', '2018-06-OKSİJEN SİSTEMİ', '2018-07-KARTUŞ', '2018-08-REVERSE OSMOS ', '2018-DEMO GİDEN CİHAZLAR']
# Lütfen okumak istediğiniz sayfanın adını girin: 2018-04-HİDROJEN PEROKSİT
# 'df_otoklav_/Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2018' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO       SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2018/036  2018-01-23 00:00:00
# 1                 DMO                        2018/037                  DMO
# ...

# %%
notebook_dir = r'/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT'  
df_hidrojen_peroksit_18 = save_and_load_csv(df_hidrojen_peroksit_18, 'df_hidrojen_peroksit_18.csv', notebook_dir) 
df_hidrojen_peroksit_18.head()
# Out:
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_18.csv' olarak kaydedildi.
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_18.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO       SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2018/036  2018-01-23 00:00:00
# 1                 DMO                        2018/037                  DMO
# 2            YURTDIŞI                        2018/038  2018-07-30 00:00:00
# 3            YURTDIŞI                        2018/039  2018-07-25 00:00:00
# 4                 DMO                        2018/086  2018-09-03 00:00:00
#
#           SİPARİŞİ VEREN/2018          KURULUM YERİ /2018          İL  \
# 0                     MERİVAN                     MERİVAN  KUZEY IRAK
# 1  DMO MERSİN BÖLGE MÜDÜRLÜĞÜ        BOR DEVLET HASTANESİ       NİĞDE
# ...

# %%
df_hidrojen_peroksit_19 = read_excel_page()
df_hidrojen_peroksit_19.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2019-Uretim_Takip.xlsx
# Dosyadaki sayfa adları: ['2019-01 OTOKLAV', '2019-02-AMELİYAT MASASI', '2019-04-HİDROJEN PEROKSİT', '2019-05-YIKAMA', '2019-06-OKSİJEN SİSTEMİ', '2019-07-KARTUŞ', '2019-08-REVERSE OSMOS ']
# Lütfen okumak istediğiniz sayfanın adını girin: 2019-04-HİDROJEN PEROKSİT
# 'df_otoklav_/Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2019' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2019/018     2019-02-08
# 1                 DMO                        2019/039     2019-02-19
# 2                ÖZEL                             NaN     2019-03-22
# ...

# %%
notebook_dir = r'/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT'  
df_hidrojen_peroksit_19 = save_and_load_csv(df_hidrojen_peroksit_19, 'df_hidrojen_peroksit_19.csv', notebook_dir) 
df_hidrojen_peroksit_19.head()
# Out:
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_19.csv' olarak kaydedildi.
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_19.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2019/018     2019-02-08
# 1                 DMO                        2019/039     2019-02-19
# 2                ÖZEL                             NaN     2019-03-22
# 3                ÖZEL                        2019/073     2019-03-26
# 4                ÖZEL                        2019/128     2019-03-26
#
#    SİPARİŞİ VEREN/2018          KURULUM YERİ /2018  DİYARBAKIR ÜRÜN MODELİ  \
# 0    MME LLC,ALEXANDER           MME LLC,ALEXANDER     UKRAYNA       GP 80
# 1  DMO GENEL MÜDÜRLÜĞÜ  ETİMESGUT DEVLET HASTANESİ      ANKARA      GP 120
# ...

# %%
df_hidrojen_peroksit_20 = read_excel_page()
df_hidrojen_peroksit_20.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2020-Uretim_Takip.xlsx
# Dosyadaki sayfa adları: ['2020-01 OTOKLAV', '2020-02-AMELİYAT MASASI', '2020-04-HİDROJEN PEROKSİT', '2020-05-YIKAMA', '2020-06-OKSİJEN SİSTEMİ', '2020-07-KARTUŞ', '2020-08-REVERSE OSMOS ']
# Lütfen okumak istediğiniz sayfanın adını girin: 2020-04-HİDROJEN PEROKSİT
# 'df_otoklav_/Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2020' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2020/041     2020-02-03
# 1            YURTDIŞI                        2020/149     2020-02-21
# 2            YURTDIŞI                        2019/345     2020-03-17
# ...

# %%
notebook_dir = r'/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT'  
df_hidrojen_peroksit_20 = save_and_load_csv(df_hidrojen_peroksit_20, 'df_hidrojen_peroksit_20.csv', notebook_dir) 
df_hidrojen_peroksit_20.head()
# Out:
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_20.csv' olarak kaydedildi.
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_20.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2020/041     2020-02-03
# 1            YURTDIŞI                        2020/149     2020-02-21
# 2            YURTDIŞI                        2019/345     2020-03-17
# 3                 DMO                        2019/348     2020-04-29
# 4                 DMO                        2019/349     2020-04-29
#
#          SİPARİŞİ VEREN/2018         KURULUM YERİ /2018          İL  \
# 0    MED İNSPİRE TEKNOLOGİES    MED İNSPİRE TEKNOLOGİES  ÖZBEKİSTAN
# 1             MODERN MEDİCAL             MODERN MEDİCAL        IRAK
# ...

# %%
df_hidrojen_peroksit_21 = read_excel_page()
df_hidrojen_peroksit_21.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2021-Uretim_Takip.xlsx
# Dosyadaki sayfa adları: ['2021-01 OTOKLAV', '2021-02-AMELİYAT MASASI', '2021-04-HİDROJEN PEROKSİT', '2021-05-YIKAMA', '2021-06-OKSİJEN', '2021-07-KARTUŞ', '2021-08-REVERSE OSMOS ']
# Lütfen okumak istediğiniz sayfanın adını girin: 2021-04-HİDROJEN PEROKSİT
# 'df_otoklav_/Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2021' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2020/411     2021-01-13
# 1            YURTDIŞI                        2018/342     2021-01-14
# 2                 DMO                        2021/165     2021-02-02
# ...

# %%
notebook_dir = r'/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT' 
df_hidrojen_peroksit_21 = save_and_load_csv(df_hidrojen_peroksit_21, 'df_hidrojen_peroksit_21.csv', notebook_dir) 
df_hidrojen_peroksit_21.head()
# Out:
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_21.csv' olarak kaydedildi.
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_21.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2020/411     2021-01-13
# 1            YURTDIŞI                        2018/342     2021-01-14
# 2                 DMO                        2021/165     2021-02-02
# 3                 DMO                        2021/018     2021-03-19
# 4                 DMO                        2021/019     2021-02-12
#
#            SİPARİŞİ VEREN/2018                    KURULUM YERİ /2018  \
# 0       CHALBI INDUSTRIES LTD.                CHALBI INDUSTRIES LTD.
# 1     HEENT INSTITUTE PVT LTD.              HEENT INSTITUTE PVT LTD.
# ...

# %%
df_hidrojen_peroksit_22 = read_excel_page()
df_hidrojen_peroksit_22.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2022-Uretim_Takip.xlsx
# Dosyadaki sayfa adları: ['2022-01 OTOKLAV', '2022-02 AMELİYAT MASASI', '2022-04 HİDROJEN PEROSİT-PLAZMA', '2022-05 YIKAMA', '2022-06 OKSİJEN', '2022-07 KARTUŞ', '2022-08 REVERSE OSMOS']
# Lütfen okumak istediğiniz sayfanın adını girin: 2022-04 HİDROJEN PEROSİT-PLAZMA
# 'df_otoklav_/Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2022' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2022/076     2022-08-25
# 1                ÖZEL                        2022/077     2022-05-10
# 2                ÖZEL                        2022/078     2022-01-06
# ...

# %%
notebook_dir = r'/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT'  
df_hidrojen_peroksit_22 = save_and_load_csv(df_hidrojen_peroksit_22, 'df_hidrojen_peroksit_22.csv', notebook_dir) 
df_hidrojen_peroksit_22.head()
# Out:
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_22.csv' olarak kaydedildi.
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_22.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0                ÖZEL                        2022/076     2022-08-25
# 1                ÖZEL                        2022/077     2022-05-10
# 2                ÖZEL                        2022/078     2022-01-06
# 3                 DMO                        2022/079     2022-04-04
# 4            YURTDIŞI                        2022/080     2022-01-06
#
#                  SİPARİŞİ VEREN/2022  \
# 0      ÇANAKKALE İL SAĞLIK MÜDÜRLÜĞÜ
# 1           ASZ KİMYA TİC. LTD. ŞTİ.
# 2  AAS SAĞLIK VE GÜZELLİK HİZM. A.Ş.
# 3         DMO ELAZIĞ BÖLGE MÜDÜRLÜĞÜ
# 4                            MERİVAN
#
# ...

# %%
df_hidrojen_peroksit_23 = read_excel_page()
df_hidrojen_peroksit_23.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2023-Uretim_Takip.xlsx
# Dosyadaki sayfa adları: ['LİSTE', '2023-01 OTOKLAV', '2023-02 AMELİYAT MASASI', '2023-03 JİNEKOLOJİK MUAYENE', '2023-04 HİDROJEN PEROSİT-PLAZMA', '2023-05 YIKAMA', '2023-06 OKSİJEN', '2023-07 KARTUŞ', '2023-08 REVERSE OSMOS', '2023-09 ULTRASONİK YIKAMA', '2023-10 KAPAMA CİHAZI', '2023-11 DİĞER CİHAZLAR', 'DEMO GİDEN CİHAZLAR', 'Sayfa1']
# Lütfen okumak istediğiniz sayfanın adını girin: 2023-04 HİDROJEN PEROSİT-PLAZMA
# 'df_otoklav_/Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2023' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2022/074     2023-11-13
# ...

# %%
notebook_dir = r'/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT'  
df_hidrojen_peroksit_23 = save_and_load_csv(df_hidrojen_peroksit_23, 'df_hidrojen_peroksit_23.csv', notebook_dir) 
df_hidrojen_peroksit_23.head()
# Out:
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_23.csv' olarak kaydedildi.
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_23.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2022/074     2023-11-13
# 1            YURTDIŞI                        2022/177     2023-12-07
# 2            YURTDIŞI                        2022/243     2023-11-08
# 3                ÖZEL                        2022/484     2023-02-18
# 4                ÖZEL                        2022/508     2023-02-16
#
#                      SİPARİŞİ VEREN/2023  \
# 0                              BANGLADEŞ
# 1                           DUBAİ - FUAR
# 2  SERVICIOS BIOMEDICIOS AROTINCO S.A.C.
# 3      ÖZEL LOKMAN HEKİM ESNAF HASTANESİ
# 4                         ALYANS MEDİKAL
#
# ...

# %%
df_hidrojen_peroksit_23_industrial = read_excel_page()
df_hidrojen_peroksit_23_industrial.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2023-Uretim_Takip-Endutriyel.xlsx
# Dosyadaki sayfa adları: ['2023-01 OTOKLAV', '2023-02 AMELİYAT MASASI', '2023-04 HİDROJEN PEROSİT-PLAZMA', '2023-05 YIKAMA', '2023-06 OKSİJEN', '2023-07 KARTUŞ', '2023-08 REVERSE OSMOS']
# Lütfen okumak istediğiniz sayfanın adını girin: 2023-04 HİDROJEN PEROSİT-PLAZMA
# 'df_otoklav_/Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2023' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2022/074     2023-11-13
# 1               İHALE                        2022/177     2023-12-07
# 2            YURTDIŞI                        2022/243     2023-11-08
# ...

# %%
notebook_dir = r'/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT'
df_hidrojen_peroksit_23_industrial = save_and_load_csv(df_hidrojen_peroksit_23_industrial, 'df_hidrojen_peroksit_23_industrial.csv', notebook_dir) 
df_hidrojen_peroksit_23_industrial.head()
# Out:
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_23.csv' olarak kaydedildi.
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_23.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2022/074     2023-11-13
# 1               İHALE                        2022/177     2023-12-07
# 2            YURTDIŞI                        2022/243     2023-11-08
# 3                ÖZEL                        2022/484     2023-02-18
# 4                ÖZEL                        2022/508     2023-02-16
#
#                      SİPARİŞİ VEREN/2023  \
# 0                              BANGLADEŞ
# 1        ÇANAKKALE 18 MART ÜNİVERSİTESİ
# 2  SERVICIOS BIOMEDICIOS AROTINCO S.A.C.
# 3      ÖZEL LOKMAN HEKİM ESNAF HASTANESİ
# 4                         ALYANS MEDİKAL
#
# ...

# %%
df_hidrojen_peroksit_24 = read_excel_page()
df_hidrojen_peroksit_24.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2024-Uretim_Takip.xlsx
# Dosyadaki sayfa adları: ['2024-01 OTOKLAV', '2024-02 AMELİYAT MASASI', '2024-04 HİDROJEN PEROSİT-PLAZMA', '2024-05 YIKAMA', '2024-06 OKSİJEN', '2024-07 KARTUŞ', '2024-08 REVERSE OSMOS']
# Lütfen okumak istediğiniz sayfanın adını girin: 2024-04 HİDROJEN PEROSİT-PLAZMA
# 'df_otoklav_/Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2024' olarak kaydedildi.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2024/141     2024-02-08
# 1                 DMO                        2024/142     2024-01-16
# 2                 DMO                        2024/143     2024-01-16
# ...

# %%
notebook_dir = r'/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT'  
df_hidrojen_peroksit_24 = save_and_load_csv(df_hidrojen_peroksit_24, 'df_hidrojen_peroksit_24.csv', notebook_dir) 
df_hidrojen_peroksit_24.head()
# Out:
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_24.csv' olarak kaydedildi.
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_24.csv' dosyasından okundu.
#   DMO-ÖZEL-İHALE-DEMO SİPARİŞ NO/İŞ EMRİ NO/TEKLİF NO SİPARİŞ TARİHİ  \
# 0            YURTDIŞI                        2024/141     2024-02-08
# 1                 DMO                        2024/142     2024-01-16
# 2                 DMO                        2024/143     2024-01-16
# 3            YURTDIŞI                        2024/144     2024-03-06
# 4            YURTDIŞI                        2024/152     2024-05-08
#
#          SİPARİŞİ VEREN/2024  \
# 0                    CEZAYİR
# 1  DMO BURSA BÖLGE MÜDÜRLÜĞÜ
# 2  DMO BURSA BÖLGE MÜDÜRLÜĞÜ
# 3                       NİCU
# 4    MERİVAN- MODERN MEDİKAL
#
#                                   KURULUM YERİ /2024       İL  \
# ...

# %%
df_hidrojen_peroksit_24_sales_analysis = read_excel_page()
df_hidrojen_peroksit_24_sales_analysis.head()
# Out:
# Lütfen çalışma dizinini girin (örnek: C:\Users\ASUS\Desktop\INT_1_PROJECT\00_Data\01_Satis_Uretim): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim
# Lütfen Excel dosyasının adını girin (örnek: 2018-Uretim_Takip.xlsx): /Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2024-Satis_Analiz.xlsx
# Dosyadaki sayfa adları: ['otoklav', 'Yıkama', 'Hidrojen Peroksit', 'Oksijen', 'Reverse Osmoz', 'Ameliyat Masası']
# Lütfen okumak istediğiniz sayfanın adını girin: Hidrojen Peroksit
# 'df_otoklav_/Users/myy/Desktop/INT_1_PROJECT/00_Data/01_Satis_Uretim/2024' olarak kaydedildi.
#    Sıra No   Modeller Satış Fiyatı (Dolar) Satış Fiyatı (Dolar).1
# 0      NaN  Teksteril              Yurtiçi               Yurtdışı
# 1      1.0        NaN                13000                  16000
# 2      2.0      TSP80                24000                  25000
# 3      3.0     TSP120                29000                  29000
# 4      4.0        NaN                29000                  29000

# %%
notebook_dir = r'/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT'
df_hidrojen_peroksit_24_sales_analysis = save_and_load_csv(df_hidrojen_peroksit_24_sales_analysis, 'df_hidrojen_peroksit_24_sales_analysis.csv', notebook_dir) 
df_hidrojen_peroksit_24_sales_analysis.head()
# Out:
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_24_sales_analysis.csv' olarak kaydedildi.
# DataFrame başarıyla '/Users/myy/Desktop/INT_1_PROJECT/01_EDA/DATA INCELEME/04_HİDROJEN PEROKSİT/df_hidrojen_peroksit_24_sales_analysis.csv' dosyasından okundu.
#    Sıra No   Modeller Satış Fiyatı (Dolar) Satış Fiyatı (Dolar).1
# 0      NaN  Teksteril              Yurtiçi               Yurtdışı
# 1      1.0        NaN                13000                  16000
# 2      2.0      TSP80                24000                  25000
# 3      3.0     TSP120                29000                  29000
# 4      4.0        NaN                29000                  29000
